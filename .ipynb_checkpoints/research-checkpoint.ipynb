# %%
# %load_ext autoreload
# %autoreload 2

from helpers import *

import bs4
import matplotlib.pyplot as plt
import nltk
import pandas as pd
import requests
from bs4 import BeautifulSoup
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import manifold
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import pdist


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

from gensim.models.ldamodel import LdaModel
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel
import numpy as np

import pickle
from langdetect import detect

from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource

output_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package punkt to /home/thomas/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/thomas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/thomas/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/thomas/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p43318">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Document Extraction

# %% [markdown]
# I chose to scrape recipes in English, French and Spanish. Since I could not find a multilingual recipe website, I scrape a different website for each language. For each recipe, three sections are scraped:
# - the recipe's title
# - the list of ingredients
# - the directions to make the recipe

# %%
RECIPES_PER_LANGUAGE = 50

# %% [markdown]
# ## Recipes in English (Allrecipes)

# %%
site_request = requests.get("https://allrecipes.com/recipes")
soup = BeautifulSoup(site_request.text, "html.parser")

# %%
links = soup.find_all('a')
recipe_links = [link for link in links if
                link.has_key("href") and link['href'].startswith(
                    "https://www.allrecipes.com/recipe/")]  # only keep links which are actually recipes

# %%
recipe_text = {"title": [], "ingredients": [], "directions": []}

for i in range(RECIPES_PER_LANGUAGE):
    print(i, recipe_links[i]["href"])
    recipe_request = requests.get(recipe_links[i]["href"])
    recipe_soup = BeautifulSoup(recipe_request.text, "html.parser")

    # extract title
    title = recipe_soup.find("h1", {"id": "article-heading_2-0"})
    recipe_text["title"].append(title.contents[0][1:])

    # extract ingredient list
    ingredients = recipe_soup.find_all("li", {"class": "mntl-structured-ingredients__list-item"})
    ingredients = [ingredient.findChildren("span", recursive=True) for ingredient in ingredients]
    ingredients = [" ".join([ingr.contents[0] if ingr.contents else "" for ingr in ingredient]) for ingredient in
                   ingredients]
    recipe_text["ingredients"].append(ingredients)

    # extract list of directions
    directions = recipe_soup.find_all("li",
                                      {"class": "comp mntl-sc-block-group--LI mntl-sc-block mntl-sc-block-startgroup"})
    directions = [direction.findChildren("p")[0].contents[0][1:-1] for direction in directions]
    recipe_text["directions"].append(directions)
# Out:
# 0 https://www.allrecipes.com/recipe/268796/spicy-gluten-free-chicken-and-cheddar-waffles-with-blackberry-maple-syrup/
# 1 https://www.allrecipes.com/recipe/269881/saucy-sriracha-franks/
# 2 https://www.allrecipes.com/recipe/275252/grilled-halloumi-with-herbed-berry-salsa/
# 3 https://www.allrecipes.com/recipe/267120/vegan-pumpkin-pancakes/
# 4 https://www.allrecipes.com/recipe/279625/pb-j-smoothie/
# 5 https://www.allrecipes.com/recipe/151593/campbells-tuna-noodle-casserole/
# 6 https://www.allrecipes.com/recipe/6874/best-ever-muffins/
# 7 https://www.allrecipes.com/recipe/35151/traditional-filipino-lumpia/
# 8 https://www.allrecipes.com/recipe/47015/quick-and-easy-pancit/
# 9 https://www.allrecipes.com/recipe/9889/seven-layer-bars/
# 10 https://www.allrecipes.com/recipe/11991/egg-noodles/
# 11 https://www.allrecipes.com/recipe/240641/salt-dough/
# 12 https://www.allrecipes.com/recipe/240522/easy-rib-eye-roast/
# 13 https://www.allrecipes.com/recipe/46982/pesto-pasta-with-chicken/
# 14 https://www.allrecipes.com/recipe/141949/doggie-birthday-cake/
# 15 https://www.allrecipes.com/recipe/282261/baked-apple-cider-donuts/
# 16 https://www.allrecipes.com/recipe/217155/dry-onion-soup-mix/
# 17 https://www.allrecipes.com/recipe/17991/stuffed-green-peppers-i/
# 18 https://www.allrecipes.com/recipe/9965/mexican-wedding-cakes-ii/
# 19 https://www.allrecipes.com/recipe/56803/very-chocolate-ice-cream/
# 20 https://www.allrecipes.com/recipe/12801/rockin-oysters-rockefeller/
# 21 https://www.allrecipes.com/recipe/13804/pumpkin-crumb-cake/
# 22 https://www.allrecipes.com/recipe/71111/down-home-chitterlings/
# 23 https://www.allrecipes.com/recipe/7506/caramel-frosting-i/
# 24 https://www.allrecipes.com/recipe/230999/sweet-jalapeno-cornbread/
# 25 https://www.allrecipes.com/recipe/240708/broccoli-and-chicken-stir-fry/
# 26 https://www.allrecipes.com/recipe/81904/parmesan-crusted-chicken/
# 27 https://www.allrecipes.com/recipe/219164/the-best-parmesan-chicken-bake/
# 28 https://www.allrecipes.com/recipe/12963/greek-lemon-chicken-soup/
# 29 https://www.allrecipes.com/recipe/18990/banana-pudding-i/
# 30 https://www.allrecipes.com/recipe/260883/caramel-cake/
# 31 https://www.allrecipes.com/recipe/42890/turkey-a-la-king/
# 32 https://www.allrecipes.com/recipe/16409/spinach-and-strawberry-salad/
# 33 https://www.allrecipes.com/recipe/25080/mmmmm-brownies/
# 34 https://www.allrecipes.com/recipe/132703/chicken-with-lemon-caper-sauce/
# 35 https://www.allrecipes.com/recipe/239712/blueberry-simple-syrup/
# 36 https://www.allrecipes.com/recipe/155182/pfeffernusse-cookies/
# 37 https://www.allrecipes.com/recipe/218772/mile-high-green-chili/
# 38 https://www.allrecipes.com/recipe/23426/almost-no-fat-banana-bread/
# 39 https://www.allrecipes.com/recipe/12384/three-berry-pie/
# 40 https://www.allrecipes.com/recipe/23074/bobs-stuffed-banana-peppers/
# 41 https://www.allrecipes.com/recipe/254328/quick-meatball-stroganoff/
# 42 https://www.allrecipes.com/recipe/19895/moon-cake/
# 43 https://www.allrecipes.com/recipe/7985/blueberry-buckle/
# 44 https://www.allrecipes.com/recipe/155047/scorpion-bowl/
# 45 https://www.allrecipes.com/recipe/269519/roasted-garlic-parmesan-fingerling-potatoes/
# 46 https://www.allrecipes.com/recipe/21066/spaghetti-sauce/
# 47 https://www.allrecipes.com/recipe/228782/the-original-fantasy-fudge/
# 48 https://www.allrecipes.com/recipe/11331/pumpkin-whoopie-pies/
# 49 https://www.allrecipes.com/recipe/214496/my-grandmothers-potato-chip-cookies/

# %%
df_recipes_en = pd.DataFrame.from_dict(recipe_text)
df_recipes_en.head()
# Out:
#                                                title  \
# 0  Spicy Gluten-Free Chicken and Cheddar Waffles ...
# 1                              Saucy Sriracha Franks
# 2           Grilled Halloumi with Herbed Berry Salsa
# 3                             Vegan Pumpkin Pancakes
# 4                                    PB & J Smoothie
#
#                                          ingredients  \
# 0  [4  fresh blackberries, 1 teaspoon ancho chile...
# 1  [1 cup ketchup, ¼ cup soy sauce, ¼ cup rice vi...
# 2  [4 ounces fresh blueberries, 3 ounces red curr...
# 3  [2 cups almond milk, 2 tablespoons distilled w...
# 4  [6  frozen strawberries, or more to taste, ¾ c...
#
#                                           directions
# 0  [Muddle 4 blackberries in the bottom of a micr...
# 1  [Mix ketchup, soy sauce, vinegar, sriracha, br...
# 2  [Place blueberries and red currants into a mix...
# 3  [Combine almond milk and vinegar together in a...
# 4  [Combine strawberries, milk, peanut butter, bl...

# %% [markdown]
# ## Recipes in French (Marmiton)

# %%
site_request = requests.get("https://www.marmiton.org/recettes/top-internautes.aspx")
soup = BeautifulSoup(site_request.text, "html.parser")

# %%
recipe_links = soup.find_all('a', {"class": "recipe-card-link"})

# %%
recipe_text = {"title": [], "ingredients": [], "directions": []}

for i in range(RECIPES_PER_LANGUAGE):
    print(i, recipe_links[i]["href"])
    recipe_request = requests.get(recipe_links[i]["href"])
    recipe_soup = BeautifulSoup(recipe_request.text, "html.parser")

    # extract title
    title = recipe_soup.find("h1", {"class": "SHRD__sc-10plygc-0 itJBWW"})
    recipe_text["title"].append(
        str(title.contents[0].string))  # NavigableStrings need to be converted to regular strings to be able to pickle

    # extract ingredients
    ingredients = recipe_soup.find_all("span", {"class": "SHRD__sc-10plygc-0 kWuxfa"})
    ingredients = [ingredient.findChildren("span", recursive=True) for ingredient in ingredients]
    ingredients = [
        " ".join([str(ingr.contents[0].string) if ingr.contents and len(ingr.contents) == 1 else "" for ingr in
                  ingredient]).strip()
        for ingredient in ingredients]
    recipe_text["ingredients"].append(ingredients)

    # extract directions
    directions = recipe_soup.find_all("p", {"class": "RCP__sc-1wtzf9a-3 jFIVDw"})
    directions = [str(direction.contents[0].string) for direction in directions]
    recipe_text["directions"].append(directions)
# Out:
# 0 https://www.marmiton.org/recettes/recette_blanquette-de-veau-facile_19219.aspx
# 1 https://www.marmiton.org/recettes/recette_tiramisu-recette-originale_12023.aspx
# 2 https://www.marmiton.org/recettes/recette_lasagnes-a-la-bolognaise_18215.aspx
# 3 https://www.marmiton.org/recettes/recette_la-vraie-moussaka-grecque_72593.aspx
# 4 https://www.marmiton.org/recettes/recette_meringue-pour-les-nuls_36610.aspx
# 5 https://www.marmiton.org/recettes/recette_pancakes_15299.aspx
# 6 https://www.marmiton.org/recettes/recette_filet-mignon-en-croute_14407.aspx
# 7 https://www.marmiton.org/recettes/recette_ramequins-fondants-au-chocolat_15816.aspx
# 8 https://www.marmiton.org/recettes/recette_le-crumble-aux-pommes-du-chat-qui-tousse_10534.aspx
# 9 https://www.marmiton.org/recettes/recette_bechamel-rapide-et-facile_14764.aspx
# 10 https://www.marmiton.org/recettes/recette_original-american-cookies-de-mike_39907.aspx
# 11 https://www.marmiton.org/recettes/recette_les-timbales-de-jeanne-saumon-a-la-mousse-de-courgettes-au-micro-ondes_21864.aspx
# 12 https://www.marmiton.org/recettes/recette_gratin-dauphinois-recette-originale_22307.aspx
# 13 https://www.marmiton.org/recettes/recette_tarte-aux-pommes-a-l-alsacienne_11457.aspx
# 14 https://www.marmiton.org/recettes/recette_pain-d-epices_11087.aspx
# 15 https://www.marmiton.org/recettes/recette_genoise-ultra-rapide-et-pourtant-si-aerienne_49844.aspx
# 16 https://www.marmiton.org/recettes/recette_galette-des-rois_10832.aspx
# 17 https://www.marmiton.org/recettes/recette_saute-de-veau-au-chorizo_17027.aspx
# 18 https://www.marmiton.org/recettes/recette_gratin-de-courgettes-rapide_17071.aspx
# 19 https://www.marmiton.org/recettes/recette_gateau-au-chocolat-des-ecoliers_20654.aspx
# 20 https://www.marmiton.org/recettes/recette_gateau-aux-pommes-facile_13493.aspx
# 21 https://www.marmiton.org/recettes/recette_pancakes-faciles-et-rapides_81518.aspx
# 22 https://www.marmiton.org/recettes/recette_cake-sale-au-jambon-et-aux-olives_18876.aspx
# 23 https://www.marmiton.org/recettes/recette_quiche-sans-pate_12744.aspx
# 24 https://www.marmiton.org/recettes/recette_the-tarte-au-citron-meringuee_22082.aspx
# 25 https://www.marmiton.org/recettes/recette_boeuf-bourguignon-rapide_19218.aspx
# 26 https://www.marmiton.org/recettes/recette_gateau-au-chocolat-fondant-rapide_166352.aspx
# 27 https://www.marmiton.org/recettes/recette_blinis-faciles-maison_22261.aspx
# 28 https://www.marmiton.org/recettes/recette_hachis-parmentier_17639.aspx
# 29 https://www.marmiton.org/recettes/recette_riz-au-lait-de-ma-maman_20380.aspx
# 30 https://www.marmiton.org/recettes/recette_creme-patissiere_35195.aspx
# 31 https://www.marmiton.org/recettes/recette_cake-au-chocolat_17391.aspx
# 32 https://www.marmiton.org/recettes/recette_gratin-dauphinois_13809.aspx
# 33 https://www.marmiton.org/recettes/recette_petits-croissants-au-saumon-fume-toast-aperitif_20483.aspx
# 34 https://www.marmiton.org/recettes/recette_gateau-au-yaourt_12719.aspx
# 35 https://www.marmiton.org/recettes/recette_crumble-simple_12173.aspx
# 36 https://www.marmiton.org/recettes/recette_pate-brisee-vite-faite_31639.aspx
# 37 https://www.marmiton.org/recettes/recette_pate-a-crepes-des-plus-raffinees_49665.aspx
# 38 https://www.marmiton.org/recettes/recette_canneles-bordelais_11439.aspx
# 39 https://www.marmiton.org/recettes/recette_veloute-de-champignons_26749.aspx
# 40 https://www.marmiton.org/recettes/recette_quiche-lorraine_30283.aspx
# 41 https://www.marmiton.org/recettes/recette_panna-cotta_17991.aspx
# 42 https://www.marmiton.org/recettes/recette_chili-con-carne-facile_15415.aspx
# 43 https://www.marmiton.org/recettes/recette_amour-de-saumon-en-papillote_21494.aspx
# 44 https://www.marmiton.org/recettes/recette_chouquettes_30622.aspx
# 45 https://www.marmiton.org/recettes/recette_poulet-a-la-moutarde-a-l-estragon-et-aux-champignons_19374.aspx
# 46 https://www.marmiton.org/recettes/recette_filet-mignon-de-porc-au-maroilles_12734.aspx
# 47 https://www.marmiton.org/recettes/recette_tiramisu-aux-speculoos_36386.aspx
# 48 https://www.marmiton.org/recettes/recette_poulet-basquaise_16969.aspx
# 49 https://www.marmiton.org/recettes/recette_clafoutis-grand-mere-aux-cerises_29896.aspx

# %%
df_recipes_fr = pd.DataFrame.from_dict(recipe_text)
df_recipes_fr.head()
# Out:
#                                          title  \
# 0  Blanquette de veau : recette traditionnelle
# 1                 Tiramisu (recette originale)
# 2                     Lasagnes à la bolognaise
# 3                    La Vraie Moussaka Grecque
# 4                    Meringue : recette facile
#
#                                          ingredients  \
# 0  [cube de bouillon de légumes, carottes, oignon...
# 1  [de  sucre roux, de  sucre vanillé, biscuits à...
# 2  [de  lasagnes, oignons jaunes, d' ail, de  cél...
# 3  [de  beurre, de  farine, de  lait, aubergines,...
# 4                 [de  sucre semoule, blancs d'oeuf]
#
#                                           directions
# 0  [Faire revenir la viande dans un peu de beurre...
# 1  [Séparer les blancs des jaunes d'oeufs., Mélan...
# 2  [Faire revenir gousses hachées d'ail et les oi...
# 3  [Préparation de la sauce tomate.\nEmincer les ...
# 4  [Quelques trucs pour bien réussir ces meringue...

# %% [markdown]
# ## Recipes in Spanish (Comedera)

# %%
site_request = requests.get("https://www.comedera.com/100-platos-comida-espanola/")
soup = BeautifulSoup(site_request.text, "html.parser")

# %%
recipe_links = soup.find_all('h3')
recipe_links = [r.contents[1] for r in recipe_links if r.find("a")][:-1]
del recipe_links[42]  # one of the recipes has a different html structure, so ignore it for simplicity

# %%
recipe_text = {"title": [], "ingredients": [], "directions": []}
for i in range(RECIPES_PER_LANGUAGE):
    print(i, recipe_links[i]["href"])
    recipe_request = requests.get(recipe_links[i]["href"])
    recipe_soup = BeautifulSoup(recipe_request.text, "html.parser")

    # extract recipe title
    title = str(recipe_links[i].contents[0].string)
    recipe_text["title"].append(title)

    # extract recipe ingredients
    ingredients = recipe_soup.find_all("li", {"class": "wprm-recipe-ingredient"})
    ingredients = [ingredient.findChildren("span") for ingredient in ingredients]
    ingredients = [" ".join([ingr.contents[0] if ingr.contents else "" for ingr in ingredient]) for ingredient in
                   ingredients]
    recipe_text["ingredients"].append(ingredients)

    # extract recipe directions
    directions = recipe_soup.find_all("div", {"class": "wprm-recipe-instruction-text"})
    directions = [direction.contents[0] for direction in directions]
    directions = [str(direction.contents[0].string) if type(direction) is bs4.element.Tag else str(direction.string) for
                  direction in directions]  # some directions are already strings and others are Spans
    recipe_text["directions"].append(directions)
# Out:
# 0 https://www.comedera.com/receta-huevos-rotos/
# 1 https://www.comedera.com/cachopo-asturiano/
# 2 https://www.comedera.com/receta-calamares-en-su-tinta/
# 3 https://www.comedera.com/como-hacer-tortilla-de-patatas-perfecta/
# 4 https://www.comedera.com/como-hacer-migas/
# 5 https://www.comedera.com/receta-de-arroz-negro/
# 6 https://www.comedera.com/pimientos-de-piquillo-rellenos-de-bacalao/
# 7 https://www.comedera.com/arroz-caldoso-con-pollo/
# 8 https://www.comedera.com/receta-cocido-madrileno/
# 9 https://www.comedera.com/receta-patatas-revolconas/
# 10 https://www.comedera.com/receta-gambas-al-ajillo/
# 11 https://www.comedera.com/como-hacer-patatas-bravas/
# 12 https://www.comedera.com/receta-para-hacer-bacalao-la-vizcaina/
# 13 https://www.comedera.com/como-hacer-fideua-de-mariscos/
# 14 https://www.comedera.com/receta-chorizo-a-la-sidra/
# 15 https://www.comedera.com/receta-bacalao-al-pil-pil/
# 16 https://www.comedera.com/como-hacer-paella-valenciana/
# 17 https://www.comedera.com/cochinillo-al-horno/
# 18 https://www.comedera.com/receta-de-gazpacho-andaluz/
# 19 https://www.comedera.com/croquetas-de-bacalao/
# 20 https://www.comedera.com/receta-de-salmorejo-cordobes/
# 21 https://www.comedera.com/como-hacer-cocido-maragato/
# 22 https://www.comedera.com/como-hacer-sopa-de-ajo/
# 23 https://www.comedera.com/receta-cordero-asado-al-horno/
# 24 https://www.comedera.com/receta-de-caldo-gallego/
# 25 https://www.comedera.com/como-hacer-pulpo-a-la-gallega/
# 26 https://www.comedera.com/receta-de-empanada-gallega/
# 27 https://www.comedera.com/crema-catalana-receta-tradicional/
# 28 https://www.comedera.com/marmitako-de-atun/
# 29 https://www.comedera.com/receta-cocochas-de-bacalao/
# 30 https://www.comedera.com/receta-de-arroz-del-senyoret/
# 31 https://www.comedera.com/receta-de-pisto-manchego/
# 32 https://www.comedera.com/receta-bacalao-ajoarriero-facil/
# 33 https://www.comedera.com/arroz-a-banda/
# 34 https://www.comedera.com/fabada-asturiana/
# 35 https://www.comedera.com/receta-merluza-en-salsa-verde/
# 36 https://www.comedera.com/receta-de-escalivada/
# 37 https://www.comedera.com/conejo-en-salmorejo/
# 38 https://www.comedera.com/receta-de-lentejas-con-chorizo/
# 39 https://www.comedera.com/como-hacer-churros/
# 40 https://www.comedera.com/patatas-a-la-importancia/
# 41 https://www.comedera.com/receta-de-olla-podrida/
# 42 https://www.comedera.com/fabes-con-almejas/
# 43 https://www.comedera.com/receta-de-papas-arrugadas/
# 44 https://www.comedera.com/patatas-a-la-riojana-receta/
# 45 https://www.comedera.com/receta-de-ensaimada-mallorquina/
# 46 https://www.comedera.com/como-hacer-porrusalda-con-bacalao/
# 47 https://www.comedera.com/chuletas-de-cordero-al-horno/
# 48 https://www.comedera.com/callos-a-la-madrilena/
# 49 https://www.comedera.com/boquerones-en-vinagre-receta/

# %%
df_recipes_sp = pd.DataFrame.from_dict(recipe_text)
df_recipes_sp.head()
# Out:
#                     title                                        ingredients  \
# 0            Huevos rotos  [2 huevos grandes, 2 patatas medianas, 1 chori...
# 1                 Cachopo  [2 filetes de ternera alargados, de alrededor ...
# 2  Chipirones en su tinta  [Calamar picado en forma de anillos: 1 kilo., ...
# 3     Tortilla de patatas  [500 gr de patatas sin pelar, 5 huevos, 1 cebo...
# 4        Migas del pastor  [1 barra de pan duro del día anterior, 6 dient...
#
#                                           directions
# 0  [Quítale la piel y corta las patatas de la for...
# 1  [Para empezar, lo ideal es que los filetes de ...
# 2  [Si los calamares no están limpios, pues a lim...
# 3  [Pela las patatas y pícalas en rodajas o gajos...
# 4  [Corta el pan en cubos pequeños y ponlo en un ...

# %%
pickle.dump(df_recipes_en, open("df_recipes_en.pkl", "wb"))
pickle.dump(df_recipes_fr, open("df_recipes_fr.pkl", "wb"))
pickle.dump(df_recipes_sp, open("df_recipes_sp.pkl", "wb"))

# %% [markdown]
# # Language Detection

# %% [markdown]
# Each recipe's language is detected by using langdetect on the recipe's directions. Using the directions is more robust since it has the largest size and the title and ingredients sometimes contain foreign words.
#
# I then chose to translate each recipe to English using googletrans. This has the downside of taking a bit of time, although not too much (~3 minutes for 150 recipes) since the recipes are often quite short. But it then greatly simplifies the preprocessing of the text and allows us to cluster all the documents at the same time without having to treat each language case by case.

# %%
df_recipes_en = pickle.load(open("df_recipes_en.pkl", "rb"))
df_recipes_fr = pickle.load(open("df_recipes_fr.pkl", "rb"))
df_recipes_sp = pickle.load(open("df_recipes_sp.pkl", "rb"))

# %%
# store all recipes in a single dataframe
df_recipes = pd.concat([df_recipes_en, df_recipes_fr, df_recipes_sp], ignore_index=True)

# %%
detected_languages = []
for directions in df_recipes["directions"].str.join(" "):  # use the directions section to detect the language
    detected_languages.append(detect(directions))

# %%
df_recipes["language"] = detected_languages

# %%
df_recipes.language.value_counts()
# Out:
# en    50
# fr    50
# es    50
# Name: language, dtype: int64

# %%
MAX_TRANS_LEN = 5000  # googletrans only accepts texts of length up to 5000

# lists to store translated sections
translated_title = []
translated_ingredients = []
translated_directions = []

for _, recipe in df_recipes.iterrows():
    if recipe["language"] != "en":  # only translate non-english text
        # translate title
        translate_chunk(recipe["title"], translated_title, recipe["language"])

        # translate list of ingredients
        joined_ingredients = ", ".join(recipe["ingredients"])
        translate_chunk(joined_ingredients, translated_ingredients, recipe["language"])

        # translate list of directions
        joined_directions = ". ".join(recipe["directions"])
        if len(joined_directions) <= MAX_TRANS_LEN:
            translate_chunk(joined_directions, translated_directions, recipe["language"])
        else:
            translated = []
            for i in range((
                                   len(joined_directions) // MAX_TRANS_LEN) + 1):  # break up text into chunks of length 5000 and translate one by one
                translate_chunk(joined_directions[MAX_TRANS_LEN * i:MAX_TRANS_LEN * (i + 1)], translated, recipe["language"])
            translated_directions.append(''.join(translated))
    else:
        translated_title.append(recipe["title"])
        translated_ingredients.append(", ".join(recipe["ingredients"]))
        translated_directions.append(". ".join(recipe["directions"]))

df_recipes["translated_title"] = translated_title
df_recipes["translated_ingredients"] = translated_ingredients
df_recipes["translated_directions"] = translated_directions

# %%
df_recipes.head()
# Out:
#                                                title  \
# 0  Spicy Gluten-Free Chicken and Cheddar Waffles ...
# 1                              Saucy Sriracha Franks
# 2           Grilled Halloumi with Herbed Berry Salsa
# 3                             Vegan Pumpkin Pancakes
# 4                                    PB & J Smoothie
#
#                                          ingredients  \
# 0  [4  fresh blackberries, 1 teaspoon ancho chile...
# 1  [1 cup ketchup, ¼ cup soy sauce, ¼ cup rice vi...
# 2  [4 ounces fresh blueberries, 3 ounces red curr...
# 3  [2 cups almond milk, 2 tablespoons distilled w...
# 4  [6  frozen strawberries, or more to taste, ¾ c...
#
#                                           directions language  \
# 0  [Muddle 4 blackberries in the bottom of a micr...       en
# 1  [Mix ketchup, soy sauce, vinegar, sriracha, br...       en
# 2  [Place blueberries and red currants into a mix...       en
# 3  [Combine almond milk and vinegar together in a...       en
# 4  [Combine strawberries, milk, peanut butter, bl...       en
#
#                                     translated_title  \
# 0  Spicy Gluten-Free Chicken and Cheddar Waffles ...
# 1                              Saucy Sriracha Franks
# 2           Grilled Halloumi with Herbed Berry Salsa
# 3                             Vegan Pumpkin Pancakes
# 4                                    PB & J Smoothie
#
#                               translated_ingredients  \
# 0  4  fresh blackberries, 1 teaspoon ancho chile ...
# 1  1 cup ketchup, ¼ cup soy sauce, ¼ cup rice vin...
# 2  4 ounces fresh blueberries, 3 ounces red curra...
# 3  2 cups almond milk, 2 tablespoons distilled wh...
# 4  6  frozen strawberries, or more to taste, ¾ cu...
#
#                                translated_directions
# 0  Muddle 4 blackberries in the bottom of a micro...
# 1  Mix ketchup, soy sauce, vinegar, sriracha, bro...
# 2  Place blueberries and red currants into a mixi...
# 3  Combine almond milk and vinegar together in a ...
# 4  Combine strawberries, milk, peanut butter, blu...

# %%
pickle.dump(df_recipes, open("df_recipes.pkl", "wb"))

# %% [markdown]
# # Text Processing

# %% [markdown]
# Each section of the recipe (plus a section containing all the others) is preprocessed following these steps:
# - Case folding
# - Punctuation removal
# - Tokenization
# - Lemmatization
# - Removal of single-character tokens
# - Removal of numbers
# - Removal of stopwords and too frequent/unfrequent words
# - Creation of bigrams (optional)
#
# I then visualize the results with word clouds of each section.

# %%
df_recipes = pickle.load(open("df_recipes.pkl", "rb"))

# %%
df_recipes["translated_text"] = df_recipes["translated_title"] + ". " + df_recipes["translated_ingredients"] + ". " +df_recipes["translated_directions"]

# %%
df_recipes.head()
# Out:
#                                                title  \
# 0  Spicy Gluten-Free Chicken and Cheddar Waffles ...
# 1                              Saucy Sriracha Franks
# 2           Grilled Halloumi with Herbed Berry Salsa
# 3                             Vegan Pumpkin Pancakes
# 4                                    PB & J Smoothie
#
#                                          ingredients  \
# 0  [4  fresh blackberries, 1 teaspoon ancho chile...
# 1  [1 cup ketchup, ¼ cup soy sauce, ¼ cup rice vi...
# 2  [4 ounces fresh blueberries, 3 ounces red curr...
# 3  [2 cups almond milk, 2 tablespoons distilled w...
# 4  [6  frozen strawberries, or more to taste, ¾ c...
#
#                                           directions language  \
# 0  [Muddle 4 blackberries in the bottom of a micr...       en
# 1  [Mix ketchup, soy sauce, vinegar, sriracha, br...       en
# 2  [Place blueberries and red currants into a mix...       en
# 3  [Combine almond milk and vinegar together in a...       en
# 4  [Combine strawberries, milk, peanut butter, bl...       en
#
#                                     translated_title  \
# 0  Spicy Gluten-Free Chicken and Cheddar Waffles ...
# 1                              Saucy Sriracha Franks
# 2           Grilled Halloumi with Herbed Berry Salsa
# 3                             Vegan Pumpkin Pancakes
# 4                                    PB & J Smoothie
#
#                               translated_ingredients  \
# 0  4  fresh blackberries, 1 teaspoon ancho chile ...
# 1  1 cup ketchup, ¼ cup soy sauce, ¼ cup rice vin...
# 2  4 ounces fresh blueberries, 3 ounces red curra...
# 3  2 cups almond milk, 2 tablespoons distilled wh...
# 4  6  frozen strawberries, or more to taste, ¾ cu...
#
#                                translated_directions  \
# 0  Muddle 4 blackberries in the bottom of a micro...
# 1  Mix ketchup, soy sauce, vinegar, sriracha, bro...
# 2  Place blueberries and red currants into a mixi...
# 3  Combine almond milk and vinegar together in a ...
# 4  Combine strawberries, milk, peanut butter, blu...
#
#                                      translated_text
# 0  Spicy Gluten-Free Chicken and Cheddar Waffles ...
# 1  Saucy Sriracha Franks. 1 cup ketchup, ¼ cup so...
# 2  Grilled Halloumi with Herbed Berry Salsa. 4 ou...
# 3  Vegan Pumpkin Pancakes. 2 cups almond milk, 2 ...
# 4  PB & J Smoothie. 6  frozen strawberries, or mo...

# %%
preprocess_section(SECTIONS[0], df_recipes, freq_thresh_upper=1, freq_thresh_lower=0)
for section in SECTIONS[1:]:
    preprocess_section(section, df_recipes)

# %%
for s in SECTIONS:
    generate_wordcloud(" ".join(list(df_recipes[f'preprocessed_{s}'])), f"{s.capitalize()} words")

# %%
pickle.dump(df_recipes, open("df_recipes_clean.pkl", "wb"))

# %% [markdown]
# # Cluster documents into logical groups

# %% [markdown]
# To vectorize the preprocessed text, I use TF-IDF. I also tried loading word vectors for fasttext, but my laptop doesn't have enough RAM to handle them :(.

# %%
df_recipes = pickle.load(open("df_recipes_clean.pkl", "rb"))

# %% [markdown]
# ## TF-IDF projection

# %% [markdown]
# To gain insight into the structure of the data, I project it down to 2 dimensions using PCA and plot the result.

# %%
visualize_projection(df_recipes, projection_method="pca")

# %% [markdown]
# I also project the data with t-SNE as it is usually better at grouping high-dimensional vectors projected on a 2d plot. By tuning the perplexity parameter, it gives slightly better results than PCA.

# %%
visualize_projection(df_recipes, projection_method="tsne")
# Out:
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# The "ingredients" section projected with t-SNE seems to produce the cleanest groupings, so I visualize it interactively with bokeh. On hovering a point, the associated recipe's name is shown, allowing me to gain insight into the meaning of each of the groups.

# %%
visualize_projection_interactive("ingredients", df_recipes, projection_method="tsne")
# Out:
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
#   <div id="a4df9fcb-ea50-414d-bf09-53c3aef40323" data-root-id="p1647" style="display: contents;"></div>

# %% [markdown]
# We can see 3 clusters of points:
# - the top one contains desserts such as tiramisu and pie, as well as some main dishes containing some crust or dough (mignon fillet in crust, salmon croissants, quiche) towards the bottom of the cluster
# - the one on the left also contains sweet recipes, as well as a few salty ones (in particular chicken)
# - the one on the right contains exclusively salty meals, in particular most of the Spanish ones

# %% [markdown]
# ## Clustering

# %% [markdown]
# Based on the above observations, I expect to be able to cluster the recipes into 2 large groups: sweet (desserts and snacks) and salty (entrées, main dishes). I also try to do a finer clustering (with for example 4 clusters which might be desserts, snacks, meat and vegetables).
#
# I attempt 3 different methods to group the recipes:
# - K-means clustering
# - DBSCAN as it should be able to better detect non-convex clusters while ignoring the 'outlier' recipes
# - Latent Dirichlet Allocation (LDA)

# %% [markdown]
# ### K-means clustering

# %% [markdown]
# #### Salty/sweet

# %% [markdown]
# Here I run K-means clustering with 2 clusters only on the ingredients section as it looks the most promising.

# %%
clusters = get_clusters("ingredients", df_recipes, 2)
visualize_projection_interactive("ingredients", df_recipes, projection_method="tsne", clusters=clusters)
# Out:
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
#   <div id="585f313f-d0df-4a0c-949f-fbeee145aada" data-root-id="p1143" style="display: contents;"></div>

# %% [markdown]
# As envisioned, the algorithm has been able to separate well between salty dishes (in black) and sweet ones (in blue). There are just a few misclassifications, mostly salty dishes with crust (such as quiche and empanadas) being grouped as sweet dishes.

# %% [markdown]
# Next, I try to run the same clustering but using the whole text. The results are not as good so in the following approaches I will focus only on the ingredients section.

# %%
clusters = get_clusters("text", df_recipes, 2)
visualize_projection_interactive("text", df_recipes, projection_method="tsne", clusters=clusters)
# Out:
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
#   <div id="c9a84509-289e-40ed-ad4f-7f4215bc69a7" data-root-id="p1297" style="display: contents;"></div>

# %% [markdown]
# #### Finer clustering

# %% [markdown]
# I now try to run K-means with more clusters.

# %%
clusters = get_clusters("ingredients", df_recipes, 3)
visualize_projection_interactive("ingredients", df_recipes, projection_method="tsne", clusters=clusters)
# Out:
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
#   <div id="1466dec5-bdbe-4dd8-9a2b-360dd9bae317" data-root-id="p1644" style="display: contents;"></div>

# %% [markdown]
# Above, with 3 clusters we now observe:
# - sweet dishes in black same as before
# - in blue salty dishes, mostly meat
# - in pink the rest of the salty dishes, including almost all the Spanish ones

# %%
clusters = get_clusters("ingredients", df_recipes, 4)
visualize_projection_interactive("ingredients", df_recipes, projection_method="tsne", clusters=clusters)
# Out:
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
#   <div id="3ede7a41-44a0-4e5b-a745-f3b8089cc39a" data-root-id="p1837" style="display: contents;"></div>

# %% [markdown]
# Above, using 4 clusters doesn't add much as it simply splits the sweet recipes into two.

# %%
clusters = get_clusters("ingredients", df_recipes, 5)
visualize_projection_interactive("ingredients", df_recipes, projection_method="tsne", clusters=clusters)
# Out:
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
#   <div id="abee7c2c-0c39-42d8-8fe9-ea24b0a6f0f5" data-root-id="p2043" style="display: contents;"></div>

# %% [markdown]
# Same thing for 5 clusters which now arbitrarily separates one of the salty dishes cluster.

# %% [markdown]
# Thus, with K-means, the best results are obtained by using only 2 clusters to separate well between salty and sweet dishes. Using 3 clusters might also be interesting to separate between sweet, meat and Spanish dishes.

# %% [markdown]
# ### DBSCAN

# %% [markdown]
# To get an idea for DBSCAN's eps parameter, I first compute the average distance between points within K-means clusters. I then do a bit more hand-tuning and arrive at eps=10 and min_samples=20 as a result.

# %%
# tf-idf on ingredients
vectorizer = TfidfVectorizer()
response = vectorizer.fit_transform(df_recipes[f"preprocessed_ingredients"])
X = response.toarray()

# standardize data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# compute average distance between points within K-means clusters to get an idea for DBSCAN's epsilon parameter
kmeans_clusters = get_clusters("ingredients", df_recipes, 2)
print(f"Average distance between points within 1st K-means cluster: {pdist(X_scaled[kmeans_clusters==0], 'euclidean').mean()}")
print(f"Average distance between points within 2nd K-means cluster: {pdist(X_scaled[kmeans_clusters==1], 'euclidean').mean()}")
# Out:
# Average distance between points within 1st K-means cluster: 14.379387580758099
# Average distance between points within 2nd K-means cluster: 11.61387409425527

# %%
clusters = get_clusters("ingredients", df_recipes, clustering_method="dbscan", eps=10, min_samples=20)
visualize_projection_interactive("ingredients", df_recipes, projection_method="tsne", clusters=clusters)
# Out:
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/thomas/miniconda3/envs/dathena-exo/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
#   <div id="fd570a71-f8cd-4e3c-bb77-68ca7eea173b" data-root-id="p44383" style="display: contents;"></div>

# %% [markdown]
# Above we observe that by using DBSCAN with roughly tuned eps and min_samples we get a similar result as with K-means clustering with 2 clusters. Although the points corresponding to salty dishes with crust are no longer misclassified as sweet dishes, a few of the sweet dishes (cake, crumble) are now classified as salty. So there has been no major improvement compared to K-means clustering.

# %% [markdown]
# ### LDA

# %% [markdown]
# As an alternative to clustering algorithms, I also try out LDA.

# %%
data_words = [[w for w in l.split()] for l in df_recipes[f'preprocessed_ingredients'].to_list()]
id2word = corpora.Dictionary(data_words)
corpus = [id2word.doc2bow(text) for text in data_words]

# %%
def flatten(l):
    return [item for sublist in l for item in sublist]

# %% [markdown]
# I do grid search to look for the best values for the num_topics, alpha and eta parameters of LDA. I use the product of topic coherence and topic diversity as a metric to compare different models.

# %%
# grid search to optimize LDA parameters
nums_topics = range(2, 6)
alphas = ['symmetric', 'asymmetric', 'auto'] + [10 ** k for k in range(-4, 2)]
etas = ['symmetric', 'auto'] + [10 ** k for k in range(-1, 3)]

best_score = 0
# try all different combinations of num_topics, alpha and eta
for n in nums_topics:
    for a in alphas:
        for e in etas:
            scores = []
            cohs = []
            divs = []
            for _ in range(5): # for each combination of parameters, run LDA 5 times and compute average score to account for randomness
                lda_model = LdaModel(corpus=corpus,
                                     id2word=id2word,
                                     num_topics=n, alpha=a, eta=e)
                cm = CoherenceModel(model=lda_model, corpus=corpus, texts=data_words, coherence='c_v') # topic coherence measures how coherent with each other the words in each topic are
                coherence = cm.get_coherence()
                diversity = len(set([t[0] for t in flatten(
                    [t[1] for t in lda_model.show_topics(num_words=10, formatted=False)])])) / (10 * n) # topic diversity measures how much the topics don't overlap
                score = coherence * diversity # optimize the product of topic coherence and topic diversity to find the best model
                scores.append(score)
                divs.append(diversity)
                cohs.append(coherence)
            sc = np.array(scores).mean()
            if sc > best_score: # look for model with best score
                best_score = sc
                print(
                    f"Avg score={sc:.2f}, avg coh={np.array(cohs).mean():.2f}, avg div={np.array(divs).mean():.2f} -- {n} topics, alpha={a}, eta={e}")
# Out:
# Avg score=0.30, avg coh=0.40, avg div=0.76 -- 2 topics, alpha=symmetric, eta=symmetric
# Avg score=0.32, avg coh=0.39, avg div=0.82 -- 2 topics, alpha=auto, eta=100

# %% [markdown]
# The best model found had 2 topics, alpha=auto and eta=100.

# %%
best_lda_model = LdaModel(corpus=corpus,
                     id2word=id2word,
                     num_topics=2, alpha="auto", eta=100)

# %%
best_lda_model.show_topics()
# Out:
# [(0,
#   '0.013*"pepper" + 0.013*"garlic" + 0.013*"taste" + 0.013*"flour" + 0.012*"onion" + 0.012*"oil" + 0.012*"egg" + 0.012*"butter" + 0.012*"white" + 0.012*"cup"'),
#  (1,
#   '0.025*"cup" + 0.018*"teaspoon" + 0.016*"sugar" + 0.014*"tablespoon" + 0.013*"egg" + 0.013*"oil" + 0.013*"white" + 0.013*"pepper" + 0.013*"butter" + 0.013*"flour"')]

# %%
dominant_topics = []
for row in best_lda_model[corpus]:
    row = sorted(row, key=lambda x: x[1], reverse=True)
    dominant_topics.append(row[0][0])
dominant_topics = np.array(dominant_topics, dtype=bool)

# %%
print(f"Recipes in topic 1: {np.array(df_recipes[f'translated_title'].tolist())[dominant_topics==0]}")
print("\n")
print(f"Recipes in topic 2: {np.array(df_recipes[f'translated_title'].tolist())[dominant_topics==1]}")
# Out:
# Recipes in topic 1: ['Veal blanquette: traditional recipe' 'Bolognese lasagna'
#  'Cream Of Mushroom' 'Vizcaína cod' 'Chorizo \u200b\u200bwith cider'
#  'Baked Segovian pig' 'Cod croquettes' 'Baked lethal lamb'
#  'Bacalao Al Ajoarriero' 'Asturian fabada' 'Chorizo lentils' 'Rotten pot'
#  'Madrid calluses']
#
#
# Recipes in topic 2: ['Spicy Gluten-Free Chicken and Cheddar Waffles with Blackberry-Maple Syrup'
#  'Saucy Sriracha Franks' 'Grilled Halloumi with Herbed Berry Salsa'
#  'Vegan Pumpkin Pancakes' 'PB & J Smoothie'
#  "Campbell's Tuna Noodle Casserole" 'Best Ever Muffins'
#  'Traditional Filipino Lumpia' 'Quick and Easy Pancit' 'Seven Layer Bars'
#  'Easy Egg Noodles' 'Salt Dough' 'Easy Rib Eye Roast'
#  'Pesto Pasta with Chicken' 'Doggie Birthday Cake'
#  'Baked Apple Cider Donuts' 'Dry Onion Soup Mix' 'Stuffed Green Peppers'
#  'Mexican Wedding Cakes II' 'Very Chocolate Ice Cream'
#  "Rockin' Oysters Rockefeller" 'Pumpkin Crumb Cake'
#  'Down Home Chitterlings' 'Caramel Frosting' 'Sweet Jalapeño Cornbread'
#  'Broccoli and Chicken Stir-Fry' 'Parmesan Crusted Chicken'
#  'The Best Parmesan Chicken Bake' 'Greek Lemon Chicken Soup'
#  'Homemade Banana Pudding' 'Caramel Cake' 'Turkey à la King'
#  'Spinach and Strawberry Salad' 'MMMMM... Brownies'
#  'Chicken with Lemon-Caper Sauce' 'Blueberry Simple Syrup'
#  'Pfeffernusse Cookies' 'Mile High Green Chili'
#  'Almost No Fat Banana Bread' 'Three Berry Pie'
#  "Bob's Stuffed Banana Peppers" 'Quick Meatball Stroganoff' 'Moon Cake'
#  'Blueberry Buckle' 'Scorpion Bowl'
#  'Roasted Garlic-Parmesan Fingerling Potatoes' 'Spaghetti Sauce'
#  'The Original Fantasy Fudge' 'Pumpkin Whoopie Pies'
#  "My Grandmother's Potato Chip Cookies" 'Tiramisu (original recipe)'
#  'The real Greek Moussaka' 'Meringue: easy recipe'
#  'Soft pancake: easy recipe' 'Mignon fillet in crust'
#  'Chocolate melting ramekins' 'The chat crumble of the cat that coughs'
#  'Quick and easy Béchamel' 'Original American Cookies of Mike'
#  'The timpani of Jeanne (salmon with zucchini mousse in the microwave)'
#  'Gratin Dauphinois (original recipe)' 'Alsatian Apple Tart' 'Gingerbread'
#  'Ultra-fast sponge cake and yet so aerial ...' 'Galette des rois'
#  'Sautéed veal at Chorizo' 'Quick zucchini gratin'
#  'Chocolate cake for schoolchildren' 'Easy apple cake'
#  'Easy and quick pancakes' 'Salt cake with ham and olives'
#  'Quich free pasta' 'Lemon meringue pie' 'Rapid bourguignon beef'
#  'Fast melting chocolate cake' 'Easy house blinis' 'Machine Parmentier'
#  "My mom's milk rice" 'Custard' 'Chocolate cake and powdered almonds'
#  'Gratin Dauphinois' 'Small smoked salmon croissants (aperitif toast)'
#  'Yogurt cake' 'Simple crumble' 'Short -lived dough'
#  'Pancake dough (most refined)' 'Bordeaux canelles'
#  'Lorraine house quiche' 'Panna cotta' 'Chile Con Carne Easy'
#  'Salmon love in Papillote' 'Chouquettes'
#  'Chicken with mustard, dragon herb and mushrooms'
#  'Tenderloin Pork In Maroilles' 'Speculoos tiramisu' 'Basque chicken'
#  'Cherry grandmother clafoutis' 'Broken eggs' 'Cachopo'
#  'Cyprus on your ink' 'Omelette' 'Pastor crumbs' 'Black rice'
#  'Piquillo Peppers Stuffed' 'Boiler rice with chicken' 'Madrid stew'
#  'Potatoes Revolconas' 'Shrimp Scampi' 'Spicy potatoes' 'Fideua'
#  'Pil pil cod' 'Valencian Paella' 'Andalusian gazpacho'
#  'Cordoba salmorejo' 'Cooked Maragato' 'Castilian garlic soup'
#  'Galician soup' 'Galician octopus' 'Galician empanada' 'Catalan cream'
#  'Tuna Marmitako' 'Kokotxas de cod in green sauce' 'SENYORET rice'
#  'Pisto Manchego' 'Plenty of rice' 'Hake in green sauce' 'escalivada'
#  'Rabbit in Salmorejo' 'Churros with chocolate' 'Potatoes to importance'
#  'Fabes with Clams' 'Writered potatoes with Canarian mojo'
#  "Potatoes Riojana's style" 'Ensaimada Mallorquina' 'Porrusalda with cod'
#  'Baked lethal lamb chops' 'Beats in vinegar']

# %% [markdown]
# We can observe that the 2 topics found are not well balanced and does not split salty and sweet recipes well. Perhaps with some more tuning the results could improve.
